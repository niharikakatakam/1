# %% [markdown]
# <a href="https://colab.research.google.com/github/niharikakatakam/1/blob/main/skin_care_product.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Default title text
#Use this to install pandas
# !pip install pandas

# %%
pip install pandas

# %%
#Importing of pandas library
import pandas as pd

# %%
#Creating a new DataFrame
df1 = pd.DataFrame({'A':[1,2,3,4],'B':['she','has','a','doll']})

# %%
df1
# Out:
#    A     B
# 0  1   she
# 1  2   has
# 2  3     a
# 3  4  doll

# %%
df1.columns
# Out:
# Index(['A', 'B'], dtype='object')

# %%
df = pd.read_csv("/product_info.csv")

# %%
df.head()

#View top rows
# Out:
#   product_id               product_name  brand_id brand_name  loves_count  \
# 0    P473671    Fragrance Discovery Set      6342      19-69         6320
# 1    P473668    La Habana Eau de Parfum      6342      19-69         3827
# 2    P473662  Rainbow Bar Eau de Parfum      6342      19-69         3253
# 3    P473660       Kasbah Eau de Parfum      6342      19-69         3018
# 4    P473658  Purple Haze Eau de Parfum      6342      19-69         2691
#
#    rating  reviews            size                      variation_type  \
# 0  3.6364     11.0             NaN                                 NaN
# 1  4.1538     13.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
# 2  4.2500     16.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
# 3  4.4762     21.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
# 4  3.2308     13.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
#
#   variation_value  ... online_only out_of_stock  sephora_exclusive  \
# ...

# %%
df.tail()

#View bottom rows
# Out:
#      product_id                                       product_name  brand_id  \
# 8489    P467659                   Couture Clutch Eyeshadow Palette      1070
# 8490    P500874                              L'Homme Eau de Parfum      1070
# 8491    P504428                   Mon Paris Eau de Parfum Gift Set      1070
# 8492    P504448                           Y Eau de Parfum Gift Set      1070
# 8493    P505461  Candy Glaze Lip Gloss Stick Duo with Hyaluroni...      1070
#
#               brand_name  loves_count  rating  reviews             size  \
# 8489  Yves Saint Laurent         2790  4.4286      7.0              NaN
# 8490  Yves Saint Laurent         2319  4.6367    556.0     2 oz / 60 mL
# 8491  Yves Saint Laurent         1475  5.0000      2.0              NaN
# 8492  Yves Saint Laurent          840     NaN      NaN              NaN
# 8493  Yves Saint Laurent          193     NaN      NaN  .11 oz / 3.2 mL
#
# ...

# %%
df.head(300)

#view first 300 rows
# Out:
#     product_id                                       product_name  brand_id  \
# 0      P473671                            Fragrance Discovery Set      6342
# 1      P473668                            La Habana Eau de Parfum      6342
# 2      P473662                          Rainbow Bar Eau de Parfum      6342
# 3      P473660                               Kasbah Eau de Parfum      6342
# 4      P473658                          Purple Haze Eau de Parfum      6342
# ..         ...                                                ...       ...
# 295     P69502                                           Tweezers      5746
# 296    P471219                             Brow Freeze Applicator      5746
# 297    P463783                                     Insta Brow Set      5746
# 298    P454992  Norvina Mini Pro Pigment Palette Vol. 3 for Fa...      5746
# 299    P449149                               Loose Setting Powder      5746
#
# ...

# %%
df.describe()

#Statistics Summary
# Out:
#           brand_id   loves_count       rating       reviews    price_usd  \
# count  8494.000000  8.494000e+03  8216.000000   8216.000000  8494.000000
# mean   5422.440546  2.917957e+04     4.194513    448.545521    51.655595
# std    1709.595957  6.609212e+04     0.516694   1101.982529    53.669234
# min    1063.000000  0.000000e+00     1.000000      1.000000     3.000000
# 25%    5333.000000  3.758000e+03     3.981725     26.000000    25.000000
# 50%    6157.500000  9.880000e+03     4.289350    122.000000    35.000000
# 75%    6328.000000  2.684125e+04     4.530525    418.000000    58.000000
# max    8020.000000  1.401068e+06     5.000000  21281.000000  1900.000000
#
#        value_price_usd  sale_price_usd  limited_edition          new  \
# count       451.000000      270.000000      8494.000000  8494.000000
# mean         91.168537       20.207889         0.070285     0.071698
# std          79.195631       24.327352         0.255642     0.258002
# ...

# %%
df.dtypes

#Kind of data present in each column
# Out:
# product_id             object
# product_name           object
# brand_id                int64
# brand_name             object
# loves_count             int64
# rating                float64
# reviews               float64
# size                   object
# variation_type         object
# variation_value        object
# variation_desc         object
# ingredients            object
# price_usd             float64
# value_price_usd       float64
# sale_price_usd        float64
# limited_edition         int64
# new                     int64
# online_only             int64
# out_of_stock            int64
# sephora_exclusive       int64
# highlights             object
# primary_category       object
# secondary_category     object
# tertiary_category      object
# child_count             int64
# child_max_price       float64
# child_min_price       float64
# dtype: object

# %%
df.isnull().sum()

#Finding out the missing values count in each and every column
# Out:
# product_id               0
# product_name             0
# brand_id                 0
# brand_name               0
# loves_count              0
# rating                 278
# reviews                278
# size                  1631
# variation_type        1444
# variation_value       1598
# variation_desc        7244
# ingredients            945
# price_usd                0
# value_price_usd       8043
# sale_price_usd        8224
# limited_edition          0
# new                      0
# online_only              0
# out_of_stock             0
# sephora_exclusive        0
# highlights            2207
# primary_category         0
# secondary_category       8
# tertiary_category      990
# child_count              0
# child_max_price       5740
# child_min_price       5740
# dtype: int64

# %%
df.columns

#view of all the columns present in the dataset
# Out:
# Index(['product_id', 'product_name', 'brand_id', 'brand_name', 'loves_count',
#        'rating', 'reviews', 'size', 'variation_type', 'variation_value',
#        'variation_desc', 'ingredients', 'price_usd', 'value_price_usd',
#        'sale_price_usd', 'limited_edition', 'new', 'online_only',
#        'out_of_stock', 'sephora_exclusive', 'highlights', 'primary_category',
#        'secondary_category', 'tertiary_category', 'child_count',
#        'child_max_price', 'child_min_price'],
#       dtype='object')

# %%
df.iloc[1:5]

#Here we are selecting rows with the help of indexing

# iloc [1:5] ---->> Start from index 1 and go till index 4 (exclude last index from condition same like of indexing in any coding language)
# Out:
#   product_id               product_name  brand_id brand_name  loves_count  \
# 1    P473668    La Habana Eau de Parfum      6342      19-69         3827
# 2    P473662  Rainbow Bar Eau de Parfum      6342      19-69         3253
# 3    P473660       Kasbah Eau de Parfum      6342      19-69         3018
# 4    P473658  Purple Haze Eau de Parfum      6342      19-69         2691
#
#    rating  reviews            size                      variation_type  \
# 1  4.1538     13.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
# 2  4.2500     16.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
# 3  4.4762     21.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
# 4  3.2308     13.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
#
#   variation_value  ... online_only out_of_stock  sephora_exclusive  \
# 1  3.4 oz/ 100 mL  ...           1            0                  0
# 2  3.4 oz/ 100 mL  ...           1            0                  0
# ...

# %%
df.iloc[0:5]

#start from 0th index and go till 4th index
# Out:
#   product_id               product_name  brand_id brand_name  loves_count  \
# 0    P473671    Fragrance Discovery Set      6342      19-69         6320
# 1    P473668    La Habana Eau de Parfum      6342      19-69         3827
# 2    P473662  Rainbow Bar Eau de Parfum      6342      19-69         3253
# 3    P473660       Kasbah Eau de Parfum      6342      19-69         3018
# 4    P473658  Purple Haze Eau de Parfum      6342      19-69         2691
#
#    rating  reviews            size                      variation_type  \
# 0  3.6364     11.0             NaN                                 NaN
# 1  4.1538     13.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
# 2  4.2500     16.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
# 3  4.4762     21.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
# 4  3.2308     13.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
#
#   variation_value  ... online_only out_of_stock  sephora_exclusive  \
# ...

# %%
df
# Out:
#      product_id                                       product_name  brand_id  \
# 0       P473671                            Fragrance Discovery Set      6342
# 1       P473668                            La Habana Eau de Parfum      6342
# 2       P473662                          Rainbow Bar Eau de Parfum      6342
# 3       P473660                               Kasbah Eau de Parfum      6342
# 4       P473658                          Purple Haze Eau de Parfum      6342
# ...         ...                                                ...       ...
# 8489    P467659                   Couture Clutch Eyeshadow Palette      1070
# 8490    P500874                              L'Homme Eau de Parfum      1070
# 8491    P504428                   Mon Paris Eau de Parfum Gift Set      1070
# 8492    P504448                           Y Eau de Parfum Gift Set      1070
# 8493    P505461  Candy Glaze Lip Gloss Stick Duo with Hyaluroni...      1070
#
# ...

# %%
df.dtypes
# Out:
# product_id             object
# product_name           object
# brand_id                int64
# brand_name             object
# loves_count             int64
# rating                float64
# reviews               float64
# size                   object
# variation_type         object
# variation_value        object
# variation_desc         object
# ingredients            object
# price_usd             float64
# value_price_usd       float64
# sale_price_usd        float64
# limited_edition         int64
# new                     int64
# online_only             int64
# out_of_stock            int64
# sephora_exclusive       int64
# highlights             object
# primary_category       object
# secondary_category     object
# tertiary_category      object
# child_count             int64
# child_max_price       float64
# child_min_price       float64
# dtype: object

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'brand_id', 'brand_name', 'loves_count',
#        'rating', 'reviews', 'size', 'variation_type', 'variation_value',
#        'variation_desc', 'ingredients', 'price_usd', 'value_price_usd',
#        'sale_price_usd', 'limited_edition', 'new', 'online_only',
#        'out_of_stock', 'sephora_exclusive', 'highlights', 'primary_category',
#        'secondary_category', 'tertiary_category', 'child_count',
#        'child_max_price', 'child_min_price'],
#       dtype='object')

# %%
df.shape
# Out:
# (8494, 27)

# %%
#Renaming of the columns

df = df.rename(columns={'Age':'How many years'})

# %%
df
# Out:
#      product_id                                       product_name  brand_id  \
# 0       P473671                            Fragrance Discovery Set      6342
# 1       P473668                            La Habana Eau de Parfum      6342
# 2       P473662                          Rainbow Bar Eau de Parfum      6342
# 3       P473660                               Kasbah Eau de Parfum      6342
# 4       P473658                          Purple Haze Eau de Parfum      6342
# ...         ...                                                ...       ...
# 8489    P467659                   Couture Clutch Eyeshadow Palette      1070
# 8490    P500874                              L'Homme Eau de Parfum      1070
# 8491    P504428                   Mon Paris Eau de Parfum Gift Set      1070
# 8492    P504448                           Y Eau de Parfum Gift Set      1070
# 8493    P505461  Candy Glaze Lip Gloss Stick Duo with Hyaluroni...      1070
#
# ...
